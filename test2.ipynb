# %%
mylist = [1, 2, 3, 4, 5]
for item in mylist:
    print("itme: ", item)
# Out:
# itme:  1
# itme:  2
# itme:  3
# itme:  4
# itme:  5

# %%
print("hello python")
myarraylist = {"a", "b", "c"}
print("myarraylist:", myarraylist)
# Out:
# hello python
# myarraylist: {'a', 'c', 'b'}

# %%
def multiply(a, b):
    return a * b

a = int(input("Enter first number: "))
b = int(input("Enter second number: ")) 

result = multiply(a, b)
print("Result of multiplication:", result)
# Out:
# Result of multiplication: 30

# %%
import math as m
print("Square root of 16 is:", m.sqrt(16))

n = int(input("Enter a number of factorial (n): "))
def factorial(n):
    if n == 0 or n == 1:
        return 1
    else:
        return n * factorial(n - 1)
    
print("Factorial of", n, "is:", factorial(n))
# Out:
# Square root of 16 is: 4.0
# Factorial of 5 is: 120

# %%
try:
    num = int(input("Enter a number to divide 100 by: "))
    print("100 divided by", num, "is:", 100 / num)
except ZeroDivisionError:
    print("Error: Cannot divide by zero.")

# %%
x = [1, 2, 3, 4, 5]
result = map(lambda i: i**2, x)
print("Squares using map and lambda:", list(result))
# Out:
# Squares using map and lambda: [1, 4, 9, 16, 25]

# %%
import pandas as pd
result = pd.Series([10, 20, 30, 40, 50], index=['a', 'b', 'c', 'd', 'e'])
print("Pandas Series:\n", result)
# Out:
# Pandas Series:
#  a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %%
import pandas as pd

df = pd.read_csv('data.csv')
#print("CTRU data:\n", df.head(25))
df = df[df["SALES CHANNEL"]=="REP"]
selectedCol = df[["YEAR", "MONTH", "COMPANY", "SALES CHANNEL"]]
print("Selected Data:\n", selectedCol)
# Out:
# Selected Data:
#        YEAR  MONTH COMPANY SALES CHANNEL
# 4     2025      3    BSNZ           REP
# 5     2025      3    BSNZ           REP
# 6     2025      3    BSNZ           REP
# 7     2025      3    BSNZ           REP
# 8     2025      3    BSNZ           REP
# ...    ...    ...     ...           ...
# 7722  2025      3    BSNZ           REP
# 7723  2025      3    BSNZ           REP
# 7724  2025      3    BSNZ           REP
# 7725  2025      3    BSNZ           REP
# 7726  2025      3    BSNZ           REP
#
# [7713 rows x 4 columns]

# %%
import pandas as pd
import numpy as np

data = {
    'Name': ['Alice', 'Bob', np.nan, 'David'],
    'Age': [24, np.nan, 22, 32],
    'Score': [88, 80, np.nan, 40]
}

df = pd.DataFrame(data)
print("Original DataFrame:\n", df)

df["Age"] = df["Age"].fillna(df["Age"].mean())
df["Score"] = df["Score"].interpolate()

print("DataFrame after handling missing values:\n", df)
# Out:
# Original DataFrame:
#      Name   Age  Score
# 0  Alice  24.0   88.0
# 1    Bob   NaN   80.0
# 2    NaN  22.0    NaN
# 3  David  32.0   40.0
# DataFrame after handling missing values:
#      Name   Age  Score
# 0  Alice  24.0   88.0
# 1    Bob  26.0   80.0
# 2    NaN  22.0   60.0
# 3  David  32.0   40.0

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [10, 20, 25, 30, 40]
plt.plot(x, y)

plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.title('Simple Line Plot')
plt.show()

# %%
import matplotlib.pyplot as plt
# Bar Chart
categories = ["A", "B", "C"]
values = [10, 20, 15]
plt.bar(categories, values, color="green")
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Bar Chart')
plt.show()
